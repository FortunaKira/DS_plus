# %% [markdown]
# <font color='DarkBlue' size=+2><b>Комментарий ревьюера</b></font><br>
# <font color='DarkBlue'>Привет, Ксения! <br>Меня зовут Олег Мазуренко, и я буду проверять этот проект. Спасибо за проделанную работу! <br>Ко мне можно обращаться на «ты». Как мне обращаться, напиши.</font><br>
# <font color='DarkBlue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font><br>
# <font color='DarkBlue'>Синий текст &mdash; просто текст комментария.</font><br>
# <font color='DarkGreen'>👌 Зеленый текст &mdash; все отлично.</font><br>
# <font color='DarkMagenta'>👉 Фиолетовый текст &mdash; сделано все правильно, однако есть рекомендации, на что стоит обратить внимание. Реализованные рекомендации позволят нам наработать опыт решения задачи разными способами или посмотреть на задачу под иным углом.</font><br>
# <font color='Red'>🛠 Красный текст &mdash; есть недочеты, они иногда бывают. </font><br><font color='DarkBlue'>Любая ошибка это возможность посмотреть на задачу с другой стороны и освоить новые знания, по этому не надо расстраиваться, если они есть.</font><br>
# <font color='DarkBlue'>Обращаю внимание, что комментарии ревьюера после проверки удалять нельзя они помогают отследить логику исправления или изменения проекта. Это дополнительный навык при обучении. Свой исправляемый код лучше тоже не удалять, а ремить #, это позволит акцентировать изменения в ходе подготовки окончательного варианта проекта.<br>
# Ответы на мои комментарии лучше тоже помечать.
# Например: </font><font color='Blue'><b>Комментарий студента</b></font><br>
# <font color='DarkBlue'><b>Теперь посмотрим, что у нас получилось!</b></font>

# %% [markdown]
# ## Исследование данных о российском кинопрокате

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Любой проект, как учебный, так и реальный, начинается с его описания, содержащего: описание контекста, цель и краткий план исследования. Надо его написать. Просто задание проекта изложить своими словами.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Добавила описание к проекту под этим комментарием</font>

# %% [markdown]
# Заказчик этого исследования — Министерство культуры Российской Федерации.
# Нужно изучить рынок российского кинопроката и выявить текущие тренды. Особо уделить внимание фильмам, которые получили государственную поддержку, и выявить, насколько такие фильмы интересны зрителю.
#
# Работать предстоит с данными, опубликованными на портале открытых данных Министерства культуры. Набор данных содержит информацию о прокатных удостоверениях, сборах и государственной поддержке фильмов, а также информацию с сайта КиноПоиск.
#
# Работа пройдёт в несколько этапов:
# - Предобработка данных
# - Общий исследовательский анализ с определением валидных для работы данных
# - Исследование картин, получивших государственнную поддержку, выявление их прибыльности и составление рекомендаций инвесторам
#
# Описание данных:
# - title — название фильма;
# - puNumber — номер прокатного удостоверения;
# - show_start_date — дата премьеры фильма;
# - type — тип фильма;
# - film_studio — студия-производитель;
# - production_country — страна-производитель;
# - director — режиссёр;
# - producer — продюсер;
# - age_restriction — возрастная категория;
# - refundable_support — объём возвратных средств государственной поддержки;
# - nonrefundable_support — объём невозвратных средств государственной поддержки;
# - financing_source — источник государственного финансирования;
# - budget — общий бюджет фильма;
# - ratings — рейтинг фильма на КиноПоиске;
# - genres — жанр фильма;
# - box_office — сборы в рублях.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Все проекты, это как часть реального исследования, за которое деньги заплатят или не заплатят. <br>А отчет читают: сначала описание, о чем идет речь и что делаем, потом выводы: что в итоге получили. А когда у заказчика в голове все сложилось, то смотрят как это делалось. То есть, в описании необходимо отразить какая цель исследования, какой контекст (особенности отрасли и данных), что мы планируем делать (план исследования). <br>И в реальном проекте не будет инструкции и задач, которые необходимо выполнить, по этому следует научиться делать описание проекта самостоятельно.</font>

# %% [markdown]
# Импортируем необходимые библиотеки:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %% [markdown]
# ### Шаг 1. Откройте файлы с данными и объедините их в один датафрейм.
#
# Объедините данные таким образом, чтобы все объекты из датасета `mkrf_movies` обязательно вошли в получившийся датафрейм.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_0" aria-expanded="false" aria-controls="collapseHint_0">Подсказка</button>
#         </div>
#         <div id="collapseHint_0" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на тип данных столбца, по которому будете соединять датафреймы. Тип данных этих столбцов должен быть одинаковым в обоих датафреймах.
#             </div>
#         </div>
#     </div>
# </div>

# %%
# загружаем данные из файла в dataframe
try:
    data_first = pd.read_csv('../datasets/mkrf_movies.csv')
    data_second = pd.read_csv('../datasets/mkrf_shows.csv')
except:
    data_first = pd.read_csv('/datasets/mkrf_movies.csv')
    data_second = pd.read_csv('/datasets/mkrf_shows.csv')

# Чтобы смотреть все столбцы
pd.set_option('display.max_columns', None)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Очень хорошо, что используется код двойной загрузки, локально и с сервера. Часто в проектах возникают ошибки именно из-за не правильного пути к датасету.</font>

# %% [markdown]
# Ознакомимся с данными из первого датасета:

# %%
print(data_first.info())
data_first.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %% [markdown]
# Ознакомимся с данными из второго датасета:

# %%
print(data_second.info())
data_second.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB
# None
#     puNumber    box_office
# 0  111000113  2.450000e+03
# 1  111000115  6.104000e+04
# 2  111000116  1.530300e+08
# 3  111000117  1.226096e+07
# 4  111000118  1.636841e+08

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Экспоненциальный формат представления чисел следовало бы преобразовать и избавиться от лишних знаков после запятых. Это можно сделать если прописать в начале настройку `pandas`, где импортируются библиотеки.<br>
# `pd.set_option('display.float_format', '{:,.2f}'.format)`
# </font>

# %% [markdown]
# Добавим информацию о box_office к первому датасету по ключу puNumber. Т.к. в data_first у puNumber тип object, а в data_second int64, перед объединением, поменяем тип данных в data_first.

# %%
data_first[~data_first['puNumber'].str.isdigit()]
# Out:
#                                   title    puNumber           show_start_date  \
# 804               Паранормальный Якутск   111004112  2012-08-24T12:00:00.000Z
# 1797  Курбан-роман. (История с жертвой)         нет  2014-05-15T12:00:00.000Z
#
#                 type       film_studio production_country    director  \
# 804   Художественный  ИП Тимофеев К.П.             Россия  К.Тимофеев
# 1797  Художественный  ФОНД "ИННОВАЦИЯ"             Россия     С.Юзеев
#
#         producer                  age_restriction  refundable_support  \
# 804          NaN  «16+» - для детей старше 16 лет                 NaN
# 1797  М.Галицкая  «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings genres
# 804                     NaN     NaN              NaN     NaN    NaN
# 1797                    NaN     NaN              NaN     NaN    NaN

# %% [markdown]
# Данные по puNumber в этих двух строках не могут быть преобразованы в целочисленные значения. На 804 строке лишние пробелы, на 1797 буквы (заменим на 0).

# %%
data_first.loc[804, 'puNumber'] = data_first.loc[804, 'puNumber'].strip()
data_first.loc[1797, 'puNumber'] = 0

# %%
# Изменение типа данных
data_first['puNumber'] = pd.to_numeric(data_first['puNumber'], errors='coerce').astype(int)
data_second['puNumber'] = data_second['puNumber'].astype(int)

# Объединение данных в общий датафрейм
full_data = (
    data_first
    .merge(
        data_second,
        how='left'
    )
)

# Проверка результата
full_data.info()
full_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   int64
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %% [markdown]
# Дальше будем работать с данными датафрейма full_data.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font> <br><font color='Red'>🛠 В задании прямо указано: "чтобы все объекты из датасета mkrf_movies обязательно вошли в получившийся датафрейм", соответственно необходимо сделать проверку и отразить это в промежуточных выводах.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Добавила вывод к шагу под этим комментарием. Проверка на корректность объединения уже показана выше =)</font>

# %% [markdown]
# На первом шаге предобработки объединили два источника данных:
# - mkrf_movies (7486 - изначальное кол-во записей)
# - mkrf_shows (3158 - изначальное кол-во записей)
#
# С помощью метода merge, за индексы взяли данные в  столбце puNumber (номера прокатных удостоверений). В результате, т.к. puNumber уникальные и выдаются на конкретный фильм, в общем датафрейме получили 7486 записей, 3158 из которых содержат информацию о номерах прокатных удостоверений. Подробнее это отображено на выводе выше (full_data.info()).

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, исправили.</font>

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# #### Шаг 2.1. Проверьте типы данных
#
# - Проверьте типы данных в датафрейме и преобразуйте их там, где это необходимо.

# %% [markdown]
# Рассмотрим все фичи и определим тип даных в формате as is -> to be:
#
# title — название фильма (object -> object)
# puNumber — номер прокатного удостоверения (int64 -> int64)
# show_start_date — дата премьеры фильма **(object -> datetime)**
# type — тип фильма (object -> object)
# film_studio — студия-производитель (object -> object)
# production_country — страна-производитель (object -> object)
# director — режиссёр (object -> object)
# producer — продюсер (object -> object)
# age_restriction — возрастная категория (object -> object)
# refundable_support — объём возвратных средств государственной поддержки (float64 -> float64)
# nonrefundable_support — объём невозвратных средств государственной поддержки (float64 -> float64)
# financing_source — источник государственного финансирования (object -> object)
# budget — общий бюджет фильма (float64 -> float64)
# ratings — рейтинг фильма на КиноПоиске **(object -> float64)**
# genres — жанр фильма (object -> object)
# box_office — сборы в рублях (float64 -> float64)
#
#
# Жирным выделено то, что требует преобразования, итого две фичи: show_start_date и ratings

# %%
full_data['show_start_date'] = pd.to_datetime(full_data['show_start_date'], format='%Y-%m-%dT%H:%M:%S.%fZ') # 2016-10-10T12:00:00.000Z
full_data['show_start_date'].head()
# Out:
# 0   2015-11-27 12:00:00
# 1   2016-09-13 12:00:00
# 2   2016-10-10 12:00:00
# 3   2016-06-10 12:00:00
# 4   2015-07-29 12:00:00
# Name: show_start_date, dtype: datetime64[ns]

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, преобразовали колонку `show_start_date` в дату.</font>

# %%
# Выведем значения в фиче ratings, которые не попадают под ожидаемое число.число
broken = full_data[full_data['ratings'].str.contains('[^0-9.]').fillna(False)]['ratings']
broken
# Out:
# 259     99%
# 811     28%
# 1053    97%
# 1341    99%
# 1805    99%
# 1874    83%
# 1899    64%
# 2126    91%
# 2146    94%
# 2438    62%
# 2680    79%
# 3139    90%
# 3431    19%
# 3439    88%
# 3446    83%
# 3514    91%
# 3585    97%
# 3786    89%
# 3948    97%
# 5332    88%
# 5455    83%
# 5821    94%
# 5910    94%
# 6426    91%
# 6616    98%
# 6737    98%
# 6882    99%
# 7159    79%
# 7277    88%
# Name: ratings, dtype: object

# %%
# Получили проценты, которые, предположу, отображают процент довольных зрителей.
# доля от 10 - новый рейтинг для таких случаев
full_data.loc[broken.index, 'ratings'] = broken.str[0] + '.' + broken.str[1]
full_data['ratings'] = pd.to_numeric(full_data['ratings'])
full_data.describe()
# Out:
#            puNumber  refundable_support  nonrefundable_support        budget  \
# count  7.486000e+03        3.320000e+02           3.320000e+02  3.320000e+02
# mean   1.351785e+08        1.186446e+07           4.898099e+07  1.272297e+08
# std    3.838218e+07        2.491656e+07           5.998012e+07  1.885883e+08
# min    0.000000e+00        0.000000e+00           0.000000e+00  0.000000e+00
# 25%    1.120250e+08        0.000000e+00           2.500000e+07  4.200000e+07
# 50%    1.210155e+08        0.000000e+00           3.000000e+07  6.864992e+07
# 75%    1.240033e+08        1.500000e+07           4.037500e+07  1.419853e+08
# max    2.310011e+08        1.800000e+08           4.000000e+08  2.305074e+09
#
#            ratings    box_office
# count  6519.000000  3.158000e+03
# mean      6.488173  7.647870e+07
# std       1.114638  2.403531e+08
# min       1.000000  0.000000e+00
# 25%       5.900000  8.623900e+04
# 50%       6.600000  2.327988e+06
# 75%       7.200000  2.397967e+07
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 В принципе процентные значения в рейтинге можно было удалить их не так много, но и такое преобразование возможно. Только надо иметь ввиду, что полученные данные коррелируют с рейтингом на сайте Кинопоиск, но не равны ему (по данным 2019 года). В чем можно убедиться, проверив несколько фильмов вручную, хотя в настоящее время данные там могут не соответствовать нашему датасету.</font>

# %% [markdown]
# Рейтинг от 1.0 до 9.9 корректный для 10-бальной шкалы, значит ненулевые значения записаны верно.

# %% [markdown]
# Посмотрим на типы теперь:

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   int64
#  2   show_start_date        7486 non-null   datetime64[ns]
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   float64
# ...

# %% [markdown]
# Всё преобразовано.

# %% [markdown]
# #### Шаг 2.2. Изучите пропуски в датафрейме
#
# - Объясните, почему заполнили пропуски определённым образом или почему не стали этого делать.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Лучше перед обработкой пропусков делать контроль размера датасета до и после обработки. Примерно вот так:</font>

# %%
# Комментарий ревьюера
temp = full_data.copy() # создаем копию датасета до преобразования
len(temp)
# Out:
# 7486

# %% [markdown]
# В 11 ячейке видндно кол-во пропусков. Сделаем как в предыдущем шаге, опишем всё по фичам:
#
# title - 7486 (нет пропусков)
# puNumber - 7486 (нет пропусков)
# show_start_date - 7486 (нет пропусков)
# type - 7486 (нет пропусков)
# age_restriction - 7486 (нет пропусков)
#
# production_country - 7484 (1% пропусков)
# film_studio - 7468 (1% пропусков)
# director - 7477 (1% пропусков)
# producer - 6918 (8% пропусков)
# ratings - 6519 (13% пропусков)
# genres - 6510 (14% пропусков)
# box_office - 3158 (58% пропусков)
# refundable_support - 332 (96% пропусков)
# nonrefundable_support - 332 (96% пропусков)
# budget - 332 (96% пропусков)
# financing_source - 332 (96% пропусков)

# %%
# ******************************************* production_country *******************************************
# Посмотрим на записи, где production_country NaN
full_data[full_data['production_country'].isna()]
# Out:
#                                                   title   puNumber  \
# 3186  Детский юмористический киножурнал "Ералаш. Ну ...  111001216
# 4441                           Мульт личности. Выпуск 5  214000410
#
#          show_start_date            type                      film_studio  \
# 3186 2016-02-09 12:00:00  Художественный  ООО "Продюсерский центр ЕРАЛАШ"
# 4441 2010-01-25 12:00:00  Художественный                              NaN
#
#      production_country                                           director  \
# 3186                NaN  Р.Светлов, И.Магитон, А.Арутюнян, Л.Мирский, А...
# 4441                NaN                                                NaN
#
#                              producer                         age_restriction  \
# 3186  ООО "Продюсерский центр ЕРАЛАШ"  «0+» - для любой зрительской аудитории
# 4441                              NaN  «0+» - для любой зрительской аудитории
#
# ...

# %%
# Всего две записи, вручную посмотрим на Кинопоиске недостающее production_country и заполним
full_data.loc[[3186, 4441], 'production_country'] = 'Россия'

# %%
# ******************************************* film_studio *******************************************
# Посмотрим на записи, где film_studio NaN
full_data[full_data['film_studio'].isna()].head()
# Out:
#                          title   puNumber     show_start_date  \
# 1293           Stars in Shorts  121011114 2014-06-03 12:00:00
# 4441  Мульт личности. Выпуск 5  214000410 2010-01-25 12:00:00
# 6105              Значит любит  111013818 2018-08-10 12:00:00
# 6181     Несейка. Младшая дочь  112007018 2018-09-01 12:00:00
# 6379              Ян Антонышев  112011818 2018-11-15 12:00:00
#
#                  type film_studio   production_country  \
# 1293   Художественный         NaN  США, Великобритания
# 4441   Художественный         NaN               Россия
# 6105   Художественный         NaN               Россия
# 6181   Документальный         NaN               Россия
# 6379   Документальный         NaN               Россия
#
#                                                director  \
# 1293  Роберт Фестингер, Руперт Френд, Джей Камен, Ни...
# 4441                                                NaN
# 6105                                        А.Краевский
# ...

# %%
# Всего 18 записей без студии. Т.к. это ~1% от df, заполним 'Без студии', но можно было бы и поискать вручную
full_data['film_studio'] = full_data['film_studio'].fillna('Без студии')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Допустимая замена пропусков заглушками.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера: Глоссарий</b></font><br>
# <font color='DarkGreen'>👌 В контексте анализа и предобработки датасета часто используютется термин: <b>Заглушка</b>. <br>Из словаря: "Заглушка — приспособление для закрывания отверстия наглухо." <br>В нашем контексте закрытие пропуска в датасете каким-то значением, совпадающим по типу с данными колонки таблицы. Как правило, для числовых данных заглушка должна быть вне диапазона значений колонки. При анализе по данной колонке заглушка или фильтруется, или включается в анализ, если сам пропуск не является ошибкой сбора данных и несет какой-то признак. <br>Частая ошибка, когда заглушке присваивается числовое значение, например `0`, а в данных колонки присутствуют символьные значения `'0'`, то при преобразовании к числовому типу произойдет слияние значимых данных таблицы и заглушки.</font>

# %%
# ******************************************* director *******************************************
# Посмотрим на записи, где director NaN
full_data[full_data['director'].isna()]
# Out:
#                                                   title   puNumber  \
# 764   Три звезды. Концерт в Waldbuhne Theater, Берли...  126003512
# 1735                           Помпеи. Британский музей  126003413
# 3840                     Зур концерт (Большой концерт).  217027010
# 4052  Ганс Сэйфуллин "Авылым чишмэлэре. Ганс Сэйфулл...  217017310
# 4298                        Изге Вэли (Святой Валентин)  217020610
# 4415                          Bon Jovi. The Circle Tour  126001710
# 4441                           Мульт личности. Выпуск 5  214000410
# 4923  Георг Фридрих Гендель. Мессия. Оратория. Корол...  126001111
# 4942             Питер Гэбриэл и New Blood Orchestra 3D  126002711
#
#          show_start_date            type                   film_studio  \
# 764  2012-12-04 12:00:00          Прочие            Райзинг Алтернатив
# 1735 2013-09-11 12:00:00          Прочие  МортуСкрин, Британский музей
# 3840 2010-06-24 12:00:00  Художественный            ООО "Барс Рекордс"
# ...

# %%
# Девять записей, уже побольше, но всё ещё в пределах приличий и могу заполнить вручную
# Получилось найти только для "Мульт личности. Выпуск 5", остальные из разряда концертов и не имеют режиссёров
full_data.loc[4441, 'director'] = 'Василий Пичул, Юрий Владовский'

# %%
# ******************************************* producer *******************************************
# Посмотрим на записи, где producer NaN
full_data[full_data['producer'].isna()].head()
# Out:
#                    title   puNumber     show_start_date            type  \
# 1   Особо важное задание  111013716 2016-09-13 12:00:00  Художественный
# 5      Остановился поезд  111013816 2016-09-13 12:00:00  Художественный
# 6        Любовь и голуби  111007013 2013-10-18 12:00:00  Художественный
# 9    Отпуск за свой счет  111019114 2014-12-01 12:00:00  Художественный
# 11          Ответный ход  111019014 2014-12-01 12:00:00  Художественный
#
#                                film_studio production_country       director  \
# 1                    Киностудия "Мосфильм"               СССР      Е.Матвеев
# 5                    Киностудия "Мосфильм"               СССР   В.Абдрашитов
# 6                    Киностудия "Мосфильм"               СССР      В.Меньшов
# 9   Киностудия "Мосфильм", Телевидение ВНР      СССР, Венгрия        В.Титов
# 11                   Киностудия "Мосфильм"               СССР  М.Туманишвили
#
#    producer                  age_restriction  refundable_support  \
# ...

# %%
# Выборочно посмотрела несколько фильмов, продюсеров у них не указано
# Функции продюсера могут выполнять также режиссёры, актёры, сценаристы (согласно Википедии)
# Поэтому, пусть producer = director если producer == NaN
full_data.loc[full_data['producer'].isna(), 'producer'] = full_data.loc[full_data['producer'].isna(), 'director']

# %%
full_data[full_data['producer'].isna()]
# Осталось 3 записи, где нет ни режиссёра, ни продюссера, такое тоже бывает, поэтому не удаляем
# Заполним оставиеся NaN 'Без режиссёра' и 'Без продюссера'
full_data['producer'] = full_data['producer'].fillna('Без продюссера')
full_data['director'] = full_data['director'].fillna('Без режиссёра')

# %%
# ******************************************* ratings *******************************************
# # Посмотрим на записи, где ratings NaN
# full_data[full_data['ratings'].isna()].head()

# # просто медианой заполнить нельзя, слишком большой процент данных и слишком малая точность
# # попробуем понять, есть ли зависимость между рейтингом, годом выпуска и жанром
# # добавим столбец с годом, чтобы можно было разделять таким образом
# full_data['show_start_year'] = full_data['show_start_date'].dt.year

# full_data.groupby(['show_start_year', 'type'])['ratings'].median()

# %%
# # Отлично видно, что у нас есть проблемы с категориями, перед тем, как продолжить, поправим их, убрав лишние пробелы
# full_data['type'] = full_data['type'].str.strip()

# %%
# # Смотрим ещё раз, повторов в типе уже нет
# grouped_ratings = full_data.pivot_table(values = 'ratings', index = ['show_start_year', 'type'], aggfunc='median').reset_index()
# grouped_ratings.head()

# %%
# # метод, который вернёт по show_start_year и movie_type медианный рейтинг из grouped_ratings
# def fill_raiting(rating, show_start_year, movie_type):
#     if rating >= 1.0:
#         return rating
#     else:
#         index = grouped_ratings.loc[grouped_ratings['show_start_year'] == show_start_year].loc[grouped_ratings['type'] == movie_type].index[0]
#         return grouped_ratings.loc[index, 'ratings'].round(1)

# %%
# full_data['ratings'] = full_data.apply(lambda x: fill_raiting(x.ratings, x.show_start_year, x.type), axis=1)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не корректная замена пропусков в колонке рейтинга медианой. <br>Данные этой колонки не являются набором случайных наблюдений. Рейтинг является агрегированным значением полученным из ревалентного количества оценок зрителей. <br>Если бы у нас была выборка оценок зрителей по отзывам на один фильм, то ее можно было считать случайными данными. Один зритель поставил отметку 1, другой 10. Одному фильм не понравился, другому понравлся. Пропуски в такой выборке можем заменить средним/медианой/модой, так как все данные относятся к одному и тому же фильму. <br>В нашем случае рейтинг как раз и является таким усреднением выборки оценок зрителей по одному фильму и является признаком именно этого фильма.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Хм, в таком случае, из идей есть только одна - заполнить NaN-ы нулями, это будет видно на графике и будет верно распознано при аналихе, т.к. если рейтинг вообще есть, то он не будет нулевым. Сделала это ниже, предыдущую обработку рейтинга закомментировала</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Можно и заглушку поставить, главное ее отфильтровывать при анализе.</font>

# %%
# ******************************************* ratings *******************************************
# Пропуски в рейтинге можем заменить только 0, 
# т.к. не можем получить эти данные в корректном виде из имеющихся источников
full_data['ratings'] = full_data['ratings'].fillna(0)

# %%
# ******************************************* genres *******************************************
# Посмотрим на записи, где genres NaN
full_data[full_data['genres'].isna()].head()
# Out:
#                                                 title   puNumber  \
# 43           Мемуары гейши (по роману Артура Голдена)  121000606
# 150                                          Жди меня  111013615
# 154  Дом из песка и тумана (по книге Андре Дюбуи III)  221037813
# 159                                 Жемчужная девушка  224011014
# 227                                        Полустанок  111026714
#
#         show_start_date            type  \
# 43  2012-12-14 12:00:00  Художественный
# 150 2015-08-25 12:00:00  Художественный
# 154 2013-10-25 12:00:00  Художественный
# 159 2014-08-28 12:00:00  Художественный
# 227 2014-12-24 12:00:00  Художественный
#
#                                            film_studio production_country  \
# 43   Коламбия Пикчерз Корпорейшн, ДримУоркс ЭсКейДж...                США
# 150                              Киностудия "Мосфильм"               СССР
# 154                                    Кобальт Пикчерз                США
# ...

# %%
# Думаю, что можно было бы найти API сервиса, который умеет по названию и доп. параметрам отдавать жанр
# Пока пойду более простым путём, оставлю эти записи с пометкой "без жанра"

full_data['genres'] = full_data['genres'].fillna('без жанра')

# %%
# ******************************************* box_office *******************************************
# Посмотрим на записи, где box_office NaN
full_data[full_data['box_office'].isna()].head()
# Out:
#                   title   puNumber     show_start_date            type  \
# 0      Открытый простор  221048915 2015-11-27 12:00:00  Художественный
# 1  Особо важное задание  111013716 2016-09-13 12:00:00  Художественный
# 2          Особо опасен  221038416 2016-10-10 12:00:00  Художественный
# 3          Особо опасен  221026916 2016-06-10 12:00:00  Художественный
# 4          Особо опасен  221030815 2015-07-29 12:00:00  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# ...

# %%
# Не получится найти итоговые сборы фильмов, поэтому можем заполнить только нулями, пробовать через медианы или другими способами будет не корректно
full_data['box_office'] = full_data['box_office'].fillna(0)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Допустимая замена пропусков заглушкой, только при анализе необходимо будет ее отфильтровывать.</font>

# %% [markdown]
# Дальше обработка полей refundable_support, nonrefundable_support, budget и financing_source. Они все описывают финансирование и источник
# Примечательно, что у них одинаковое кол-во пропусков, поэтому, предположу, что заполнены только те, где был гос. источник финансирования.

# %%
full_data[~full_data['refundable_support'].isna()].head()
# Out:
#                     title   puNumber     show_start_date            type  \
# 1281        Пока еще жива  111005313 2013-10-11 12:00:00  Художественный
# 1448  Бесславные придурки  111003314 2014-03-28 12:00:00  Художественный
# 1498            Невидимки  111004213 2013-09-10 12:00:00  Художественный
# 1524                БЕРЦЫ  111004314 2014-05-05 12:00:00  Художественный
# 1792             Братья Ч  111004414 2014-04-23 12:00:00  Художественный
#
#                                             film_studio production_country  \
# 1281  АНО содействия развитию кинематографии "Ангел-...             Россия
# 1448                         ООО "Компания "АТК-Студио"             Россия
# 1498                        ООО "Компания "РЕАЛ-ДАКОТА"             Россия
# 1524                             ООО "Студия "Пассажир"             Россия
# 1792                             ООО "Студия "Пассажир"             Россия
#
#                                   director  \
# ...

# %% [markdown]
# Т.к. нет источника, откуда эти данные можно было бы подтянуть, пока заполним всё нулями и пометкой 'Без гос. финансирования'. В разделе 2.5 ещё вернёмся к количественным значениям.

# %%
full_data['refundable_support'] = full_data['refundable_support'].fillna(0)
full_data['nonrefundable_support'] = full_data['nonrefundable_support'].fillna(0)
full_data['budget'] = full_data['budget'].fillna(0)
full_data['financing_source'] = full_data['financing_source'].fillna('Без гос. финансирования')

# %%
# Проверим пропуски теперь:
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   int64
#  2   show_start_date        7486 non-null   datetime64[ns]
#  3   type                   7486 non-null   object
#  4   film_studio            7486 non-null   object
#  5   production_country     7486 non-null   object
#  6   director               7486 non-null   object
#  7   producer               7486 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     7486 non-null   float64
#  10  nonrefundable_support  7486 non-null   float64
#  11  budget                 7486 non-null   float64
#  12  financing_source       7486 non-null   object
#  13  ratings                7486 non-null   float64
# ...

# %% [markdown]
# Пропусков не осталось, поэтому переходим дальше.

# %% [markdown]
# **Примечание: Поменяла местами Шаг 2.3 и Шаг 2.4, т.к. мне кажется лучше сначала избавиться от проблем с категориальными значениями, а потом уже смотреть дабликаты**

# %% [markdown]
# #### Шаг 2.3. Изучите категориальные значения
#
# - Посмотрите, какая общая проблема встречается почти во всех категориальных столбцах;
# - Исправьте проблемные значения в поле `type`.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_1" aria-expanded="false" aria-controls="collapseHint_1">Подсказка</button>
#         </div>
#         <div id="collapseHint_1" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# В поле <code>type</code> есть несколько значений, у которых появился пробел в начале строки. Самый простой способ их «починить» -- использовать метод <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html#pandas.Series.str.strip">.str.strip</a>. Этот метод удаляет все пробелы, которые встречаются в начале и в конце строки. Применяют его таким образом:<br>
# <code>df['type'].str.strip()</code>
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Категориальные данные находятся в стобцах:
#
# - title
# - type
# - film_studio
# - production_country
# - director
# - producer
# - age_restriction
# - financing_source
# - genres

# %%
# метод, который убирает лишние пробелы и обрабатывает для дальнейшего поиска дубликатов
def spaces_and_letters_handling(series):
    print(f"Кол-во уникальных вариантов до обработки: {len(series.unique())}")
    result = (
        series
        .str.lower()
        .replace('ё', 'е', regex=True)
        .replace(['   ', '  '], '', regex=True)
        .str.strip()
    )
    print(f"После обработки: {len(result.unique())}")
    return result

# %%
full_data['title'] = spaces_and_letters_handling(full_data['title'])
# Out:
# Кол-во уникальных вариантов до обработки: 6772
# После обработки: 6760

# %%
full_data['type'] = spaces_and_letters_handling(full_data['type'])
# Out:
# Кол-во уникальных вариантов до обработки: 8
# После обработки: 6

# %%
full_data['type'] = spaces_and_letters_handling(full_data['type'])
# Out:
# Кол-во уникальных вариантов до обработки: 6
# После обработки: 6

# %%
full_data['film_studio'] = spaces_and_letters_handling(full_data['film_studio'])
# Out:
# Кол-во уникальных вариантов до обработки: 5491
# После обработки: 5421

# %%
full_data['production_country'] = spaces_and_letters_handling(full_data['production_country'])
# Out:
# Кол-во уникальных вариантов до обработки: 950
# После обработки: 932

# %%
full_data['director'] = spaces_and_letters_handling(full_data['director'])
# Out:
# Кол-во уникальных вариантов до обработки: 4813
# После обработки: 4784

# %%
full_data['producer'] = spaces_and_letters_handling(full_data['producer'])
# Out:
# Кол-во уникальных вариантов до обработки: 5715
# После обработки: 5688

# %%
full_data['age_restriction'] = spaces_and_letters_handling(full_data['age_restriction'])
# Out:
# Кол-во уникальных вариантов до обработки: 5
# После обработки: 5

# %%
full_data['financing_source'] = spaces_and_letters_handling(full_data['financing_source'])
# Out:
# Кол-во уникальных вариантов до обработки: 4
# После обработки: 4

# %%
full_data['genres'] = spaces_and_letters_handling(full_data['genres'])
# Out:
# Кол-во уникальных вариантов до обработки: 743
# После обработки: 743

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Согласно заданию, необходимо найти общую проблему в категориальных данных. Надо ее описать в промежуточном выводе.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Добавила описание общей проблемы под комментарием</font>

# %% [markdown]
# Основная общая проблема категориальных значений, похоже, человеческий фактор:
# - Двойные/тройные пробелы
# - Отрицание буквы 'ё' и замене её на 'е'
# - Регистр
# - Лишние пробелы в начале и/или конце строки (в данном случае, на мой взгляд, это самое частое)
#
# Это всё приводит к дубликатам, а дубликаты затрудняют анализ, т.к. одни и те же по сути категории становятся с точки зрения комьютера разными. Метод, который применился к категориальным столбцам исправляет как раз эти ситуации.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Общая проблема многих колонок с категориальными данными связана с тем, что они содержат очень много уникальных значений из-за того, что в них идет перечисления отдельных признаков.</font>

# %% [markdown]
# #### Шаг 2.4. Изучите дубликаты в датафрейме
# - Проверьте, есть ли в данных дубликаты. Опишите причины, которые могли повлиять на появление дублей.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не проверены  явные (полные) дубликаты, что требуется в задании. </font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Добавила проверку и очистку явных дубликатов в самый конец шага 2.4, т.к. если их не было в самом начале, после обработки не явных дубликатов, они могли появиться</font>

# %%
full_data.head(40)
# Out:
#                                                 title   puNumber  \
# 0                                    открытый простор  221048915
# 1                                особо важное задание  111013716
# 2                                        особо опасен  221038416
# 3                                        особо опасен  221026916
# 4                                        особо опасен  221030815
# 5                                   остановился поезд  111013816
# 6                                     любовь и голуби  111007013
# 7                                   любовь и сигареты  221074614
# 8                                  отпетые мошенники.  121011416
# 9                                 отпуск за свой счет  111019114
# 10  превосходство борна /по одноименной новелле ро...  221031416
# 11                                       ответный ход  111019014
# 12  малышка на миллион /по мотивам рассказов ф.х.т...  221011415
# ...

# %%
# В production_country когда есть несколько стран, они записаны, то через ',', то через '-'. Нужно привести к одному виду
full_data['production_country'] = full_data['production_country'].apply(lambda x: ', '.join([x.strip() for x in x.split('-')]))

# %%
# Посмотрим на уникальный список стран, которые вообще встречаются
unique_counties = np.array([])
for elem in full_data['production_country'].unique():
    county_list = []
    for county in elem.split(','):
        county_list.append(county.strip())
    unique_counties = np.append(unique_counties, county_list)
    unique_counties.flatten()

print(sorted(np.unique(unique_counties, axis=0)))
# Out:
# ['', '2019', 'cша', 'австралия', 'австрия', 'азербайджан', 'албания', 'англия', 'аргентина', 'армения', 'афганистан', 'багамские острова', 'бангладеш', 'бахрейн', 'беларусь', 'белоруссия', 'бельгия', 'бенльгия', 'болгария', 'босния', 'босния и герцеговина', 'бразилия', 'великобритания', 'венгрия', 'венесуэла', 'внр', 'вьетнам', 'гаити', 'гдр', 'германия', 'германя', 'герцеговина', 'голландия', 'гонконг', 'греция', 'грузия', 'дания', 'западный берлин', 'израиль', 'изриль', 'индия', 'индонезия', 'иран', 'ирландия', 'исландия', 'испания', 'италия', 'к;анада', 'казахстан', 'каймановы острова', 'камбоджа', 'канада', 'катар', 'кения', 'кипр', 'киргизия', 'китай', 'кнр', 'княжество андорра', 'колумбия', 'корея', 'куба', 'ланка', 'латвия', 'ливан', 'литва', 'люксембург', 'македония', 'малайзия', 'мальта', 'мексика', 'монако', 'монголия', 'н.зеландия', 'непал', 'нидерланды', 'новая зеландия', 'норвегия', 'норвения', 'оаэ', 'объединенные арабские эмираты', 'пакистан', 'палестина', 'панама', 'п
# ...

# %% [markdown]
# '' -> не обращаем внимания, скорее всего, получилось при дублировании запятой в поле
# 2019 -> вообще не страна, нужно поправить

# %%
# ''
full_data.query("production_country == ''") # дествительно таких записей нет
# Out:
# Empty DataFrame
# Columns: [title, puNumber, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, nonrefundable_support, budget, financing_source, ratings, genres, box_office]
# Index: []

# %%
# 2019
display(full_data.query("production_country == '2019'")) # одна запись, найдём страну вручную
full_data.loc[7247, 'production_country'] = 'германия'
# Out:
#              title   puNumber     show_start_date            type  \
# 7247  дело коллини  121027219 2019-09-19 12:00:00  художественный
#
#                                             film_studio production_country  \
# 7247  константин филм, глобал скрин, севен пикчерз сван               2019
#
#                  director                                           producer  \
# 7247  марко кройцпайнтнер  мартин московиц, кристоф мюллер, марсель хартг...
#
#                       age_restriction  refundable_support  \
# 7247  «16+» - для детей старше 16 лет                 0.0
#
#       nonrefundable_support  budget         financing_source  ratings  \
# 7247                    0.0     0.0  без гос. финансирования      7.4
#
#                        genres  box_office
# 7247  детектив,драма,криминал         0.0

# %% [markdown]
# Есть ряд неявных дубликатов, нужны замены, описанные дальше в методе counties_handling:

# %%
# метод, который приводит названия стран к единому формату
def counties_handling(series):
    print(f"Кол-во уникальных вариантов до обработки: {len(series.unique())}")
    result = (
        series
        .replace(['cша', 'сща'], 'сша', regex=True) # cша (что перед австралией при применённой сортировке, внимание на раскладку)
        .replace('белоруссия', 'беларусь', regex=True)
        .replace('бенльгия', 'бельгия', regex=True)
        .replace('англия', 'великобритания', regex=True)
        .replace('внр', 'венгрия', regex=True)
        .replace('изриль', 'израиль', regex=True)
        .replace('к;анада', 'канада', regex=True)
        .replace('кнр', 'китай', regex=True)
        .replace('изриль', 'израиль', regex=True)
        .replace('н.зеландия', 'новая зеландия ', regex=True)
        .replace('норвения', 'норвегия', regex=True)
        .replace('оаэ', 'объединенные арабские эмираты', regex=True)
        .replace('порртугалия', 'португалия', regex=True)
        .replace('пнр', 'польша', regex=True)
        .replace('республика армения', 'армения', regex=True)
        .replace('республика беларусь', 'беларусь', regex=True)
        .replace('республика казахстан', 'казахстан', regex=True)
        .replace('республика кипр', 'кипр', regex=True)
        .replace('республика узбекистан', 'узбекистан', regex=True)
        .replace('чешская республика', 'чехия', regex=True)
        .replace('чсср', 'ссср', regex=True)
        .replace(['германя', 'гдр', 'западный берлин'], 'германия', regex=True)
        .replace(['республика корея', 'ю.корея', 'южная корея'], 'корея', regex=True) # (т.к. допускаем, что Северная Корея не выпускает фильмы за свои пределы)
        .replace(['фрация', 'фрг'], 'франция', regex=True)
        .replace(['пуэрто', 'рико'], 'пуэрто рико', regex=True)
        .replace(['босния', 'герцеговина'], 'босния и герцеговина', regex=True)
        .replace(['ланка', 'шри'], 'шри-ланка', regex=True)
        .replace('шри-ланка-ланка', 'шри-ланка', regex=True)
        .replace('босния и босния и герцеговина и босния и герцеговина', 'босния и герцеговина', regex=True) # костыль
        .replace('босния и босния и герцеговина', 'босния и герцеговина', regex=True) # костыль
        .replace('пуэрто пуэрто рико пуэрто рико', 'пуэрто рико', regex=True) # костыль
        .replace('пуэрто пуэрто рико', 'пуэрто рико', regex=True) # костыль
        .str.strip()
    )
    print(f"После обработки: {len(result.unique())}")
    return result

# %%
full_data['production_country'] = counties_handling(full_data['production_country'])
# Out:
# Кол-во уникальных вариантов до обработки: 811
# После обработки: 789

# %%
unique_counties = np.array([])
for elem in full_data['production_country'].unique():
    county_list = []
    for county in elem.split(','):
        county_list.append(county.strip())
    unique_counties = np.append(unique_counties, county_list)
    unique_counties.flatten()

print(sorted(np.unique(unique_counties, axis=0)))
# Out:
# ['', 'австралия', 'австрия', 'азербайджан', 'албания', 'аргентина', 'армения', 'афганистан', 'багамские острова', 'бангладеш', 'бахрейн', 'беларусь', 'бельгия', 'болгария', 'босния и герцеговина', 'бразилия', 'великобритания', 'венгрия', 'венесуэла', 'вьетнам', 'гаити', 'германия', 'голландия', 'гонконг', 'греция', 'грузия', 'дания', 'израиль', 'индия', 'индонезия', 'иран', 'ирландия', 'исландия', 'испания', 'италия', 'казахстан', 'каймановы острова', 'камбоджа', 'канада', 'катар', 'кения', 'кипр', 'киргизия', 'китай', 'княжество андорра', 'колумбия', 'корея', 'куба', 'латвия', 'ливан', 'литва', 'люксембург', 'македония', 'малайзия', 'мальта', 'мексика', 'монако', 'монголия', 'непал', 'нидерланды', 'новая зеландия', 'норвегия', 'объединенные арабские эмираты', 'пакистан', 'палестина', 'панама', 'парагвай', 'перу', 'польша', 'португалия', 'пуэрто рико', 'россия', 'румыния', 'сенегал', 'сербия', 'сингапур', 'словакия', 'словения', 'ссср', 'сша', 'таджикистан', 'таиланд', 'тайвань', 'ту
# ...

# %%
full_data.head(3)
# Out:
#                   title   puNumber     show_start_date            type  \
# 0      открытый простор  221048915 2015-11-27 12:00:00  художественный
# 1  особо важное задание  111013716 2016-09-13 12:00:00  художественный
# 2          особо опасен  221038416 2016-10-10 12:00:00  художественный
#
#                                          film_studio production_country  \
# 0  тачстоун пикчерз, кобальт пикчерз, бикон пикче...                сша
# 1                              киностудия "мосфильм"               ссср
# 2  юниверсал пикчерз, кикстарт продакшнз, марк пл...                сша
#
#             director                                           producer  \
# 0      кевин костнер          дэвид валдес, кевин костнер, джейк эбертс
# 1          е.матвеев                                          е.матвеев
# 2  тимур бекмамбетов  джим лемли, джейсон нетер, марк е.платт, яйн смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# ...

# %%
# проверим, могли ли задублироваться фильмы, определим дубликаты по ряду столбцов
full_data[full_data.duplicated(subset=['title', 'show_start_date', 'type', 'film_studio'], keep=False)]
# Out:
#                                   title   puNumber     show_start_date  \
# 1300                          эпидемия_  121025713 2013-10-07 12:00:00
# 1301                          эпидемия_  221035513 2013-10-07 12:00:00
# 1475                             оторвы  121006514 2014-04-07 12:00:00
# 1476                             оторвы  221013214 2014-04-07 12:00:00
# 2191                последние пять лет.  221008115 2015-03-25 12:00:00
# 2192                последние пять лет.  121005715 2015-03-25 12:00:00
# 2752  пингвиненок пороро: большие гонки  224001915 2015-04-15 12:00:00
# 2753  пингвиненок пороро: большие гонки  124001915 2015-04-15 12:00:00
# 3086                          анархисты  221003916 2016-02-03 12:00:00
# 3087                          анархисты  121002316 2016-02-03 12:00:00
# 4042                              бугай  224021210 2010-09-24 12:00:00
# 4043                              бугай  124001210 2010-09-24 12:00:00
# ...

# %%
full_data[full_data.duplicated(subset=['title', 'show_start_date', 'type', 'film_studio', 'puNumber'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [title, puNumber, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, nonrefundable_support, budget, financing_source, ratings, genres, box_office]
# Index: []

# %% [markdown]
# Несмотря на то, что выше при поиске дубликатов по 'title', 'show_start_date', 'type', 'film_studio' дубликаты нашлись, у них не дублируются puNumber. Думаю, что не нужно эти дубликаты удалять. Не уверена, можно ли их объединить, суммировав box_office, поэтому пока оставляю так

# %% [markdown]
# Проверим будли в самом puNumber

# %%
full_data.loc[full_data['puNumber'].duplicated(keep=False)]
# Out:
#                                                   title   puNumber  \
# 4638                   как жениться и остаться холостым  221154310
# 4639  иоанна - женщина на папском престоле /по роман...  221154310
# 5067                                    анализируй это!  221054410
# 5068                                     анализируй то!  221054410
#
#          show_start_date            type  \
# 4638 2010-12-17 12:00:00  художественный
# 4639 2010-12-17 12:00:00  художественный
# 5067 2010-05-25 12:00:00  художественный
# 5068 2010-05-25 12:00:00  художественный
#
#                                             film_studio  \
# 4638  ше вам, скрипт ассосье, тэ фэ 1 фильм продюксь...
# 4639  константин фильм, а эр ди дегето фильм, дюне ф...
# 5067          уорнер бразерс, вилладж роудшоу филмз лтд
# 5068  уорнер бразерс, виллидж роадшоу пикчерз, эн-пи...
#
#                              production_country        director  \
# 4638                                    франция    эрик лартиго
# ...

# %% [markdown]
# Видим, что дубли есть. Предположим, у фильма "как жениться и остаться холостым" всё верно, рассмотрим "иоанна - женщина на папском престоле".

# %%
full_data[full_data['title'].str.contains('иоанна - женщина на папском престоле')]
# Out:
#                                                   title   puNumber  \
# 4050  иоанна - женщина на папском престоле /по роман...  121005410
# 4513  иоанна - женщина на папском престоле /по роман...  221141710
# 4639  иоанна - женщина на папском престоле /по роман...  221154310
#
#          show_start_date            type  \
# 4050 2010-03-25 12:00:00  художественный
# 4513 2010-12-03 12:00:00  художественный
# 4639 2010-12-17 12:00:00  художественный
#
#                                             film_studio  \
# 4050  константин фильм, а эр ди дегето фильм, дюне ф...
# 4513  константин фильм, а эр ди дегето фильм, дюне ф...
# 4639  константин фильм, а эр ди дегето фильм, дюне ф...
#
#                              production_country        director  \
# 4050  германия, великобритания, италия, испания  зенке вортманн
# 4513  германия, великобритания, италия, испания  зенке вортманн
# 4639  германия, великобритания, италия, испания  зенке вортманн
#
# ...

# %% [markdown]
# Фильм трижды запускался под тремя разными прокатными удостоверениями, при этом 4513 и 4639 очень близки по времени запуска, скорее всего, 4639 - дуль и его можно убрать

# %%
full_data = full_data.drop(index=4639)

# %% [markdown]
# 5067 и 5068 очень похожи, но всё же разные,по возрастной категории, стране и рейтингу. Есть некоторые отличия в том, как русскими буквами записаны иностранные имена и названия. Т.к. это одна запись и тысяч, ничего не испортится, если я удалю 5068

# %%
full_data = full_data.drop(index=5068)

# %% [markdown]
# Посмотрим на наличие явных дубликатов:

# %%
full_data.duplicated().sum()
# full_data.drop_duplicates().resen_index(drop=True)
# Out:
# 0

# %% [markdown]
# Т.к. явных дубликатов нет, закомментировала саму их очистку

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, теперь правильно. 👍</font>

# %% [markdown]
# #### Шаг 2.5. Проверьте количественные значения
#
# - Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_budget" aria-expanded="false" aria-controls="collapseHint_budget">Подсказка</button>
#         </div>
#         <div id="collapseHint_budget" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на описание столбца <code>budget</code>. Как этот столбец соотносится с двумя другими: <code>refundable_support</code> и <code>nonrefundable_support</code>?
#             </div>
#         </div>
#     </div>
# </div>

# %%
full_data.describe()
# Out:
#            puNumber  refundable_support  nonrefundable_support        budget  \
# count  7.484000e+03        7.484000e+03           7.484000e+03  7.484000e+03
# mean   1.351556e+08        5.263228e+05           2.172861e+06  5.644076e+06
# std    3.836159e+07        5.781874e+06           1.615105e+07  4.753444e+07
# min    0.000000e+00        0.000000e+00           0.000000e+00  0.000000e+00
# 25%    1.120250e+08        0.000000e+00           0.000000e+00  0.000000e+00
# 50%    1.210154e+08        0.000000e+00           0.000000e+00  0.000000e+00
# 75%    1.240033e+08        0.000000e+00           0.000000e+00  0.000000e+00
# max    2.310011e+08        1.800000e+08           4.000000e+08  2.305074e+09
#
#            ratings    box_office
# count  7484.000000  7.484000e+03
# mean      5.649653  3.227148e+07
# std       2.412212  1.606214e+08
# min       0.000000  0.000000e+00
# 25%       5.400000  0.000000e+00
# 50%       6.400000  0.000000e+00
# 75%       7.200000  1.081533e+06
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно, что для анализа количественных данных посмотрели сводную статистику.</font>

# %% [markdown]
# Из всех количественных показателей имеет смысл проверить только budget, т.к. остальные или уже обрабатывались (ratings), или их не нужно рассматривать как количественные (puNumber), или провалидировать не получится (refundable_support, nonrefundable_support и box_office).
#
# Для начала, посмотрим, есть ли ситуации, когда фильм спонсировался гос-вом, но budget оказался меньше, чем сумма спонсирования:

# %%
full_data.query('refundable_support + nonrefundable_support > budget')
# Out:
#                        title   puNumber     show_start_date            type  \
# 2053                     14+  111023614 2014-12-19 12:00:00  художественный
# 2058               дуxless 2  111000415 2015-01-26 12:00:00  художественный
# 2472             воин (2015)  111017315 2015-09-28 12:00:00  художественный
# 2532                 бармен.  111009615 2015-05-26 12:00:00  художественный
# 2615     савва. сердце воина  114001715 2015-07-21 12:00:00    анимационный
# 2684          тряпичный союз  111010215 2015-06-08 12:00:00  художественный
# 2788      срочно выйду замуж  111017115 2015-09-30 12:00:00  художественный
# 2874       помню - не помню!  111004916 2016-03-01 12:00:00  художественный
# 3047  любовь с ограничениями  111008216 2016-04-29 12:00:00  художественный
# 3565       притяжение (2016)  111018116 2016-12-16 12:00:00  художественный
# 3675                чудо-юдо  114001817 2017-06-27 12:00:00    анимационный
# ...

# %% [markdown]
# Да. такие случаи обнаружились, в них везде бюджет = 0. Видимо, какая-то ошибка или сбой, но корректное условие должно выглядеть: **refundable_support + nonrefundable_support <= budget**. Удалять это 17 записей не хотелось бы, т.к. фильмов, которые имеют гос. спонсоров всего 332, в таком случае будет удалено 5% информации, когда её и так 4% от всего датасета. Попробуем определить "средний" объём гос. поддержки:

# %%
support_percent = ((full_data['refundable_support'] + full_data['nonrefundable_support']) / full_data['budget']).median().round(2)
support_percent
# Out:
# 0.61

# %%
records_to_fill = full_data.query('refundable_support + nonrefundable_support > budget').index
full_data.loc[records_to_fill, 'budget'] = (full_data.loc[records_to_fill, 'refundable_support'] + full_data.loc[records_to_fill, 'nonrefundable_support']) / support_percent
full_data.loc[records_to_fill]
# Out:
#                        title   puNumber     show_start_date            type  \
# 2053                     14+  111023614 2014-12-19 12:00:00  художественный
# 2058               дуxless 2  111000415 2015-01-26 12:00:00  художественный
# 2472             воин (2015)  111017315 2015-09-28 12:00:00  художественный
# 2532                 бармен.  111009615 2015-05-26 12:00:00  художественный
# 2615     савва. сердце воина  114001715 2015-07-21 12:00:00    анимационный
# 2684          тряпичный союз  111010215 2015-06-08 12:00:00  художественный
# 2788      срочно выйду замуж  111017115 2015-09-30 12:00:00  художественный
# 2874       помню - не помню!  111004916 2016-03-01 12:00:00  художественный
# 3047  любовь с ограничениями  111008216 2016-04-29 12:00:00  художественный
# 3565       притяжение (2016)  111018116 2016-12-16 12:00:00  художественный
# 3675                чудо-юдо  114001817 2017-06-27 12:00:00    анимационный
# ...

# %% [markdown]
# #### Шаг 2.6. Добавьте новые столбцы

# %% [markdown]
# - Создайте столбец с информацией о годе проката. Выделите год из даты премьеры фильма.

# %%
# Для удобства анализа по разным периодам, добавляем столбец, содержащий год премьеры
full_data['show_start_year'] = full_data['show_start_date'].dt.year
full_data['show_start_year'].head()
# Out:
# 0    2015
# 1    2016
# 2    2016
# 3    2016
# 4    2015
# Name: show_start_year, dtype: int64

# %% [markdown]
# - Создайте два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_2" aria-expanded="false" aria-controls="collapseHint_2">Подсказка</button>
#         </div>
#         <div id="collapseHint_2" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Чтобы создать такие столбцы, лучше всего использовать собственную функцию. Эту функцию можно применить к двум столбцам сразу.
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Добавим ещё основную страну, чтобы можно было смотреть по ней тоже

# %%
# функция, которая берёт первое значение из строки, разбитой ',' и записывает его в фичу, названную по форме main_{название переданной колонки}
def add_main_columns(data_frame, columns):
    for column in columns:
        data_frame[f'main_{column}'] = data_frame[column].str.split(',').str[0]
    return data_frame

full_data = add_main_columns(full_data, ['director', 'genres', 'production_country'])

# %%
# На всякий случай, проверим новые столбцы на корректность записи
full_data['main_production_country'] = spaces_and_letters_handling(full_data['main_production_country'])
full_data['main_genres'] = spaces_and_letters_handling(full_data['main_genres'])
full_data['main_director'] = spaces_and_letters_handling(full_data['main_director'])
# Out:
# Кол-во уникальных вариантов до обработки: 76
# После обработки: 76
# Кол-во уникальных вариантов до обработки: 29
# После обработки: 29
# Кол-во уникальных вариантов до обработки: 4583
# После обработки: 4583

# %%
full_data['main_genres'].unique()
# дубликатов нет среди возможных жанров
# Out:
# array(['боевик', 'драма', 'фантастика', 'мелодрама', 'мюзикл', 'комедия',
#        'триллер', 'ужасы', 'мультфильм', 'без жанра', 'военный',
#        'документальный', 'фэнтези', 'криминал', 'приключения', 'аниме',
#        'детектив', 'для взрослых', 'семейный', 'концерт', 'история',
#        'короткометражка', 'детский', 'спорт', 'биография', 'вестерн',
#        'музыка', 'фильм-нуар', 'реальное тв'], dtype=object)

# %%
full_data['main_production_country'].unique()
# дубликатов нет среди возможных стран
# Out:
# array(['сша', 'ссср', 'франция', 'германия', 'великобритания',
#        'чехословакия', 'новая зеландия', 'канада', 'россия', 'гонконг',
#        'ирландия', 'чехия', 'люксембург', 'япония', 'аргентина', 'дания',
#        'австрия', 'италия', 'китай', 'швеция', 'испания', 'мексика',
#        'бразилия', 'чили', 'австралия', 'португалия', 'исландия', 'корея',
#        'бельгия', 'украина', 'босния и герцеговина', 'норвегия',
#        'швейцария', 'греция', 'грузия', 'финляндия', 'израиль', 'иран',
#        'нидерланды', 'узбекистан', 'турция', 'сербия', 'киргизия',
#        'индия', 'польша', 'армения', 'юар', 'беларусь', 'румыния',
#        'болгария', 'индонезия', 'таиланд', 'малайзия', 'азербайджан',
#        'парагвай', 'уругвай', 'хорватия', 'венгрия', 'эстония',
#        'венесуэла', 'македония', 'кипр', 'перу', 'княжество андорра',
#        'казахстан', 'объединенные арабские эмираты', 'голландия', 'литва',
# ...

# %%
len(full_data['main_director'].unique())
# очень трудно обработать такой большой список имён, учитывая разные написания иностранных имён, сокращения имени и т.п., 
# поэтому дубликаты не буду убирать, предполагая, что имя режиссёра не повлияет на исследование
# Out:
# 4583

# %% [markdown]
# - Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %%
full_data['budget_proportion'] = round((full_data['refundable_support'] + full_data['nonrefundable_support']) / full_data['budget'], 2)
full_data['budget_proportion'] = full_data['budget_proportion'].fillna(0) # сразу избавимся от NaN
full_data.query("budget_proportion > 0").head()
# Out:
#                     title   puNumber     show_start_date            type  \
# 1281        пока еще жива  111005313 2013-10-11 12:00:00  художественный
# 1448  бесславные придурки  111003314 2014-03-28 12:00:00  художественный
# 1498            невидимки  111004213 2013-09-10 12:00:00  художественный
# 1524                берцы  111004314 2014-05-05 12:00:00  художественный
# 1792             братья ч  111004414 2014-04-23 12:00:00  художественный
#
#                                             film_studio production_country  \
# 1281  ано содействия развитию кинематографии "ангел-...             россия
# 1448                         ооо "компания "атк-студио"             россия
# 1498                        ооо "компания "реал-дакота"             россия
# 1524                             ооо "студия "пассажир"             россия
# 1792                             ооо "студия "пассажир"             россия
#
#                                   director  \
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно сделано задание по созданию колонок.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Здесь ожидаются обобщающие выводы по разделу предобработки данных.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Добавила их под этим комментарием</font>

# %% [markdown]
# **Вывод по предобработке данных**
# В ходе этого этапа данные были приведенв к виду, с которым можно приступать к анализу:
# - Преобразованы типы данных, где они не соответвовали действительности:
# -- ratings — рейтинг фильма на КиноПоиске (object -> float64)
# -- show_start_date — дата премьеры фильма (object -> datetime)
# - Обработаны пропуски в значениях (в итоге размер df стал 7486 записей):
# -- production_country - 1% *пропусков от изначального df* (дальше =/=) были прописаны вручную по данным от Кинопоиска
# -- film_studio - 1% =/= заполнено заглушками 'Без студии'
# -- director - 1% =/= для "Мульт личности. Выпуск 5" нашла и прописала руками, остальные заглушками 'Без режиссёра'
# -- producer - 8% =/= заполнила по правилу producer = director если producer == NaN, остальные заглушками 'Без продюссера'
# -- ratings - 13% =/= заполнила нулями
# -- genres - 14% =/= заполнила заглушками 'без жанра'
# -- box_office - 58% =/= заполнила нулями
# -- refundable_support - 96% =/= заполнила нулями
# -- nonrefundable_support - 96% =/= заполнила нулями
# -- budget - 96% =/= заполнила нулями
# -- financing_source - 96% =/= заполнила заглушками 'Без гос. финансирования'
# - Изучены категориальные значения (title, type, film_studio, production_country, director, producer, age_restriction, financing_source, genres), методом spaces_and_letters_handling убраны:
# -- Двойные/тройные пробелы
# -- Замена 'ё' на 'е'
# -- Регистр приведён к нижнему
# -- Лишние пробелы в начале и/или конце строки (в данном случае, на мой взгляд, это самое частое)
# - Изучены и убраны дубликаты:
# -- В production_country когда есть несколько стран, они записаны, то через ',', то через '-', приведено к записи через ','
# -- Одну и ту же страну можно записать несколькими способами и даже опечататься, метод counties_handling это исправил
# -- По ряду столбцов ('title', 'show_start_date', 'type', 'film_studio') проверили дубликаты, их не обнаружилось (явных, тем более)
# -- Проверены дубликаты puNumber, для их устранения убрано 2 раписи из df
# - Проверены количественные значения:
# -- Исправлена ситуация, когда refundable_support + nonrefundable_support > budget. Бюджет в этих случаях был 0, а заполнен по медианному проценту поддержки от государства. Если источник финансирования был, он в среднем давал 61% от общего бюджета
# - Добавлены новые столбцы для удобства анализа:
# -- show_start_year - год премьеры
# -- main_production_country - основная страна
# -- main_genres - основной жанр
# -- main_director - главный режиссёр
# -- budget_proportion - процент гос. поддержки бюджета

# %% [markdown]
# ### Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# Создадим отдельную сводную таблицу, в  которой по годам соберём показатели:
# - количества фильмов, что вышли на прокат
# - суммы прокатных сборов
# - медианный и средний показатель по прокатным сбором среди "ненулевых"
# - общего числа выпущенных фильмов (даже если они не попали в прокат)
# - процентом фильмов, что вышли в прокат от общего числа

# %%
not_zero_box_office = full_data.query('box_office > 0')
pivot_full_data = not_zero_box_office.pivot_table(index='show_start_year', values='box_office', aggfunc=['count', 'sum', 'median', 'mean'])
pivot_full_data = pivot_full_data.set_axis(['rental_count', 'rental_sum', 'rental_median', 'rental_mean'], axis='columns')

pivot_full_data['year_count'] = full_data.pivot_table(index='show_start_year', values='box_office', aggfunc='count')['box_office']
pivot_full_data['rental_percentage'] = pivot_full_data['rental_count'] / pivot_full_data['year_count']  * 100
pivot_full_data
# Out:
#                  rental_count    rental_sum  rental_median   rental_mean  \
# show_start_year
# 2010                      101  2.428654e+06       1710.000  2.404608e+04
# 2011                      109  1.410276e+07       3000.000  1.293832e+05
# 2012                      123  6.955423e+06       6220.000  5.654815e+04
# 2013                      179  2.979971e+07       3580.000  1.664788e+05
# 2014                      273  7.444952e+09      20400.000  2.727089e+07
# 2015                      462  3.949737e+10    5003450.150  8.549213e+07
# 2016                      525  4.786630e+10    3915041.020  9.117390e+07
# 2017                      357  4.856371e+10    9968340.000  1.360328e+08
# 2018                      475  4.966840e+10    8891102.210  1.045651e+08
# 2019                      530  4.842571e+10    4627798.345  9.136926e+07
#
#                  year_count  rental_percentage
# show_start_year
# 2010                    983          10.274669
# ...

# %% [markdown]
# - Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах. Проанализируйте, как эта доля менялась по годам. Сделайте вывод о том, какой период полнее всего представлен в данных.

# %% [markdown]
# Начнём с визуализации количества премьер фильмов по годам:

# %%
(
    pivot_full_data
    .plot(y='year_count', kind='bar', figsize=(10, 5), legend=False, grid=True, color='green', alpha=0.6)
)
plt.title('Выпуск фильмов по годам независимо от выхода в прокат')
plt.ylabel('Кол-во фильмов')
plt.xlabel('Год премьеры')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Что является фактом выхода в прокат фильма? Наличие сборов в прокате. Не все фильмы с установленной датой премьеры попадают в прокат, а здесь это не учтено.</font><br>
# <font color='Red'>🛠 Визуализация данных графиками и диаграммами подразумевает подписи всех осей и название графика  на русском языке, при необходимости наличие меток. Это относится ко всем графикам/диаграммам проекта и является критической ошибкой.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# По первому комментарию, тут я как раз хотела посмотреть на то, какое распределение вообще у премьер без учёта выхода в прокат. **pivot_full_data**, по которому построен графики в этом разделе **= not_zero_box_office.pivot_table....**, где **not_zero_box_office = full_data.query('box_office > 0')**, за исключением двух столбцов (year_count и rental_percentage), там действительно нет отбора 'box_office > 0'. year_count в сравнении с rental_count дают представление о том, сколько существующих фильмов не вышли в прокат по данным df. Это соотношение подтверждается графиком на основе rental_percentage. Поэтому, не очень поняла комментарий, если тут всё же ошибка в срезе, напиши, пожалуйста, поподробнее)<br><br>
# По второму комментарию, добавила заголовок графику</font>

# %% [markdown]
# Особых примечаний и тенденций нет, можно только сказать, что самый "выпускной" год - 2010.

# %% [markdown]
# Попробуем оценить годы в денежном показатели, обратимся к медиане и к сумме:

# %%
(
    pivot_full_data
    .plot(y='rental_sum', kind='bar', figsize=(10, 5), legend=False, grid=True, color='green', alpha=0.6)
)
plt.title('Суммарные сборы прокатов по годам')
plt.ylabel('Общий сбор по прокатам (млрд)')
plt.xlabel('Год')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Поправила, добавлен заголовок</font>

# %%
(
    pivot_full_data
    .plot(y='rental_median', kind='bar', figsize=(10, 5), legend=False, grid=True, color='green', alpha=0.6)
)
plt.title('Медианные сборы прокатов по годам')
plt.ylabel('Медианный сбор по прокатам (млрд)')
plt.xlabel('Год')
plt.show()

# %% [markdown]
# По этим показателям всё, что происходит до 2015 года выглядит бесприбыльно. Скорее всего, это была не благотворительность, а большие пробелы в данных, которым мы не сможем восполнить при текущих доступных источниках.

# %% [markdown]
# А теперь посмотрим на их прокатные показатели:

# %%
(
    pivot_full_data
    .plot(y='rental_count', kind='bar', figsize=(10, 5), legend=False, grid=True, color='green', alpha=0.6)
)
plt.title('Количество прокатов по годам')
plt.ylabel('Кол-во прокатов')
plt.xlabel('Год премьеры')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Поправила, добавлен заголовок</font>

# %% [markdown]
# Тут основная тенденция на повышение кол-ва прокатных фильмов, несмотря на то, что в 2010 бум по выпуску, в прокат прошли не многие, но мы дальше ещё перейдём к изучению этого соотношения.

# %% [markdown]
# box_office известно не для всех фильмов, а это основной показатель, по которому возможно понять, насколько фильм стал популярен. Определим долю данных, которые можем анализировать:

# %%
not_zero = not_zero_box_office['puNumber'].count()
zero = full_data.query('box_office == 0')['puNumber'].count()
print(f'Кол-во фильмов, для которых известны прокатные сборы: {not_zero}, не известны: {zero}')
print(f"Доля данных, по которым есть информация о прокатных сборах: {(not_zero / full_data['puNumber'].count() * 100).round(2)}")
# Out:
# Кол-во фильмов, для которых известны прокатные сборы: 3134, не известны: 4350
# Доля данных, по которым есть информация о прокатных сборах: 41.88

# %% [markdown]
# Менее 50% от всех данных, очень плохой показатель, но улучшить его не представляется возможным, поэтому будем работать с тем, что есть с оговоркой, что точность может оказаться очень низкой. Попробуем посмотреть в динамике

# %%
(
    pivot_full_data
    .plot(y='rental_percentage', kind='bar', figsize=(10, 5), legend=False, grid=True, color='green', alpha=0.6)
)
plt.title('Процент фильмов, что вышли в прокат')
plt.ylabel('%')
plt.xlabel('Год')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Поправила, добавлен заголовок</font>

# %% [markdown]
# Грфик получился очень похожим на предыдущий, где рассматривалось количество прокатов. Можно сделать очевидный вывод, чем больше фильмов вышло в прокат, тем выше доля проката.

# %% [markdown]
# **Вывод** по периоду, который можно считать валидным для дальнейшего анализа
# Т.к. нас в первую очередь интересует сам прокат, а не успехи киностудий в выпуске фильмов, нельзя работать с периодом, где доля проката от всех фильмов мень по крайней мере 50%. Более того, если обратиться к таблицам, оторажающим доходность прокатов, то нормальные показатели там только с 2015 года, до этого явные потери в данных.
# **Дальше работаем со срезом с 2015 до 2019 года**, т.к. он наиболее полно представлен в данных.

# %%
valid_data = full_data.query('show_start_year > 2014')
print(f"От изначального df осталось {(valid_data['puNumber'].count() / full_data['puNumber'].count() * 100).round(2)}% данных")
valid_data.head()
# Out:
# От изначального df осталось 51.43% данных
#                   title   puNumber     show_start_date            type  \
# 0      открытый простор  221048915 2015-11-27 12:00:00  художественный
# 1  особо важное задание  111013716 2016-09-13 12:00:00  художественный
# 2          особо опасен  221038416 2016-10-10 12:00:00  художественный
# 3          особо опасен  221026916 2016-06-10 12:00:00  художественный
# 4          особо опасен  221030815 2015-07-29 12:00:00  художественный
#
#                                          film_studio production_country  \
# 0  тачстоун пикчерз, кобальт пикчерз, бикон пикче...                сша
# 1                              киностудия "мосфильм"               ссср
# 2  юниверсал пикчерз, кикстарт продакшнз, марк пл...                сша
# 3  юниверсал пикчерз, кикстарт продакшнз, марк пл...                сша
# 4  юниверсал пикчерз, кикстарт продакшнз, марк пл...                сша
#
# ...

# %% [markdown]
# - Изучите, как менялась динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?

# %% [markdown]
# Т.к. на предыдущем шаге было принято решение, рассматривать только период с 2015 до 2019, обновим набор данных в сводной таблице:

# %%
valid_pivot_full_data = pivot_full_data.query('show_start_year > 2014')
valid_pivot_full_data
# Out:
#                  rental_count    rental_sum  rental_median   rental_mean  \
# show_start_year
# 2015                      462  3.949737e+10    5003450.150  8.549213e+07
# 2016                      525  4.786630e+10    3915041.020  9.117390e+07
# 2017                      357  4.856371e+10    9968340.000  1.360328e+08
# 2018                      475  4.966840e+10    8891102.210  1.045651e+08
# 2019                      530  4.842571e+10    4627798.345  9.136926e+07
#
#                  year_count  rental_percentage
# show_start_year
# 2015                    705          65.531915
# 2016                    818          64.180929
# 2017                    505          70.693069
# 2018                    891          53.310887
# 2019                    930          56.989247

# %% [markdown]
# Посмотрим на суммарные сборы по годам более детально:

# %%
(
    valid_pivot_full_data
    .plot(y='rental_sum', kind='line', figsize=(10, 5), legend=False, grid=True, color='red', alpha=0.6)
)
plt.title('Сумма прокатных сборов по годам')
plt.ylabel('Общий сбор (млрд)')
plt.xlabel('Год')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Исправлено, добавлен заголовок</font>

# %% [markdown]
# Минимальный показатель в 2015 году, немного меньше 4 млрд, максимальный - в 2018 году, почти 5 млрд. При этом в 2015 год, предположу, самый вероятно подверженный потерям данных, если вспомнить картину до отсечения записей до 2015 года. Поэтому, в среднем, за последние 4 представленных года общий сбор по прокатам составил около 4.8 млрд.

# %% [markdown]
# - С помощью сводной таблицы посчитайте среднюю и медианную сумму сборов для каждого года.

# %% [markdown]
# Сумма сборов складывается из отдельных сборов по фильмам. выпущенным в прокат, посмотрим на эти показатели:

# %%
(
    valid_pivot_full_data
    .plot(y=['rental_median', 'rental_mean'], kind='line', figsize=(10, 5), legend=False, grid=True, color=['blue','green'], alpha=0.6, label= ['Медиана', 'Среднее'])
)
plt.title('Среднее и медиана сборов по годам')
plt.ylabel('Сборы (млрд)')
plt.xlabel('Год')
plt.legend()
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Исправлено, добавлен заголовок</font>

# %% [markdown]
# По графику очень хороши видно, что средний сбор гораздо больше медианного на всё протяжении, самый пик в 2017 году. Такой большой отрыв может быть из-за того, что отдельные прокаты получили очень большой сбор и средний показатель сместился. Проверим это:

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильный вывод. Средняя и медианная сумма сбора существенно отличаются - средняя сумма сборов оказывается в разы выше медианной. Это значит, что среди фильмов есть явные звезды, приносящие своим создателям существенную долю от общего проката. А сборы большей части фильмов весьма скромные.</font>

# %%
valid_data.plot(y='box_office', kind='box', figsize=(10, 10), grid=True)
plt.title('Распределение сборов по их суммам')
plt.ylabel('Сборы (млрд)')
plt.xlabel('Прокатный сбор')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Исправлено, добавлены названия осей и заголовок</font>

# %% [markdown]
# Да, действительно основная масса сборов находится в диапазоне до 0.5 млрд, максимальный сбор же превышает 3 млрд.

# %% [markdown]
# - Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Можно сократить строку колонки возрастной категории до значения возраста в кавычках, для этого следует извлечь из строки символы до разделителя `-`.</font>

# %%
# age_restriction
(
    valid_data
    .pivot_table(index='show_start_year', columns='age_restriction', values='box_office', aggfunc='sum')
    .plot(kind='line', figsize=(15, 7), legend=True, grid=True, alpha=0.6)
)
plt.title('Суммарные прокатные сборы по годам для возрастных категорий')
plt.ylabel('Прокатные сборы (млрд)')
plt.xlabel('Год')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Исправлено, добавлен заголовок</font>

# %% [markdown]
# Очевидно, что фильмы категории 16+ с 2015 до 2017 активно увеличивали свои прокатные сборы, потом, с 2017 до 2019 начали сдавать позиции, но всё ещё оставались лидерами по сборам. У фильмов категории 12+ история обратная, с 2015 до 2017 их сборы уменьшались с каждым годом, а с 2017 до 2019 начали расти и достигли в конце примерно той же отметки, что и 16+. Предположу, что такое может происходить из-за смены аудитории, когда подростки подрастают, их уже могут заинтересовать и более лёгкие к просмтору произведения. Основная разница этих возрастных категорий в том, что в фильмах 16+ относительно 12+ могут содержаться:
# - информация о наркотических средствах
# - отдельные бранные слова и (или) выражения, не относящиеся к нецензурной брани
# - изображение или описание несчастного случая, аварии, катастрофы, заболевания, смерти без натуралистического показа их последствий
#
# Другой вариант - изменение качества контента в категории 12+, стремительно развивается графика, в произведениях важен уже не только смысл, но и подача, и картинка (звуковое сопровождение тоже имеет значение).
# Либо на момент 2017 года детей (12+) стало просто больше, чем подростков (16+), но эта теория кажется менее вероятной, т.к. дети не соблюдают возрастные ограничения по собственному выбору =)
# Склоняюсь к первому варианту или второму варианту.
#
# По другим категориям, между 6+ и 18+ видно некоторое сходство динамики, за исключением 2016 года. Предположу, что это просто самый стабильный пласт, который просматривается "в быту", то, что обычно в семьях идёт на телевизоре (пусть даже на фоне). Отдельно в самом низу 0+, видимо, если этот контент и смотрят, много он не собирает. Для того, чтобы получить категорию 0+ нужно соблюсти самые жёсткие рамки, оригинальный сюжет придумать сложно.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Можно дополнить анализ средними и медианными значениями сборов по возрастной категории, в качестве иллюстрации построить диаграммы размаха.</font>

# %%
# Комментарий ревьюера 2
import seaborn as sns
temp = full_data.copy()
# для удобства укоротим названия категорий
def get_first_value(s, sep = ','):  # Функция для выбора первого элемента из перечисления
    value_lst = s.split(sep=sep)
    return value_lst[0]

temp['age_restriction'] = temp['age_restriction'].apply(lambda x: get_first_value(x, sep='-'))
# сохраним маску для среза по годам
year_mask = temp['show_start_year'] >= 2015

plt.figure(figsize=(8, 8))
(sns.boxplot(data = temp.loc[year_mask], y = 'box_office', x='age_restriction', showfliers=False, showmeans=True)
    .set(title = 'Кассовые сборы в зависимости от возрастной категории', 
         xlabel = 'Возрастные категории', ylabel = 'Кассовый сбор'))
plt.text(0, 1.18e8,'Треугольник показывает среднее значение')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Для интерпретации диаграмм размаха помогает вспомнить, что означают боксплоты. В данном случае расположение боксплота и медианы показывают у какой возрастной категории стабильно высокие сборы.</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не сделаны промежуточные выводы по данному разделу проекта.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Добавила вывод код этим комментарием</font>

# %% [markdown]
# **Вывод по исследовательскому анализу**
# На этапе исследовательского анализа определили наиболее валидный период для работы, это с 2015 до 2019 года. После отсечения не корректных данных осталось 51.43% данных от изначального df. Посмотрели:
# - соотношение количества выпущенных фильмов и фильмов, что прошли в прокат: именно по этому показателю было принято решение о выбросе данных до 2015 года, т.к. там нет информации о прокатных сборах, вероятно, это невосполнимые потери при текущих доступных источниках данных.
# - изменение медианной и средней стоимости проката фильмов по годам: они сильно различаются, среднее во много раз превышает медианное, значит, в большинстве случаев, сборы у фильмов не большие, но есть отдельные хиты, которые составляют существенную долю общего проката.
# - суммы сборов фильмов по годам в разрезах их возрастных категорий: самым доходным на выбранном периоде являлся 16+, но дальше эта картина может измениться, т.к. набирает популярность 12+, а 16+ идёт на спад по сборам.

# %% [markdown]
# ### Шаг 4. Исследуйте фильмы, которые получили государственную поддержку
#
# На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг.

# %% [markdown]
# Выберем фильмы, которые получали гос. поддержку:

# %%
supported = valid_data.query("financing_source != 'без гос. финансирования'")
supported.head()
# Out:
#                                           title   puNumber  \
# 1854  тайна сухаревой башни. чародей равновесия  114000115
# 1870                     а зори здесь тихие..._  111002915
# 1903                                  призрак_.  111001815
# 1912                                   ведьма .  111002215
# 2058                                  дуxless 2  111000415
#
#          show_start_date            type  \
# 1854 2015-02-18 12:00:00    анимационный
# 1870 2015-03-16 12:00:00  художественный
# 1903 2015-03-02 12:00:00  художественный
# 1912 2015-03-05 12:00:00  художественный
# 2058 2015-01-26 12:00:00  художественный
#
#                                             film_studio production_country  \
# 1854                         ооо "студия "мастер-фильм"             россия
# 1870                        ооо "компания "реал-дакота"             россия
# 1903                                 ооо "водород 2011"             россия
# ...

# %%
supported['financing_source'].unique()
# Out:
# array(['министерство культуры', 'фонд кино',
#        'министерство культуры, фонд кино'], dtype=object)

# %% [markdown]
# Всего два источника финансирования:
# - министерство культуры
# - фонд кино
#
# И 3 варианта источников финансирования фильма, первым, вторым и обоими.

# %% [markdown]
# Посмотрим на жанры:

# %%
(
    supported
    .pivot_table(index='main_genres', values='financing_source', aggfunc='count')
    .sort_values(by='financing_source', ascending=False)
    .plot(kind='bar', figsize=(15, 7), legend=True, grid=True, alpha=0.6)
)
plt.title('Распределение кол-ва произведений по жанрам при гос. финансировании')
plt.ylabel('Кол-во произведений')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Исправлено, добавлен заголовок</font>

# %%
(
    supported
    .pivot_table(index='main_genres', values=['refundable_support', 'nonrefundable_support', 'budget'], aggfunc='sum')
    .sort_values(by='budget', ascending=False)
    .plot(kind='bar', figsize=(15, 7), legend=True, grid=True, alpha=0.6)
)
plt.title('Распределение бюджета по жанрам при гос. финансировании')
plt.ylabel('Сумма поддержки (млрд)')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Исправлено, добавила заголовок</font>

# %% [markdown]
# За 2015-2019 год финансировались произведения множества жанров, самые финансируемые:
# - драма
# - комедия
# - мультфильм
# - приключения
# - фантастика
# - фентези
# И ещё 15 менее финансиуемых.
#
# Количество снятых произведений каждого жанра визуально связано с объёмами финансирования, особенно для первых трёх.
#
# Перейдём к анализу окупаемости. Сначала проверим данные о сборах для текущей выборки:

# %%
supported.query('box_office > 0')['puNumber'].count()
# Out:
# 300

# %%
supported.query('box_office <= 0')['puNumber'].count()
# Out:
# 14

# %% [markdown]
# Из 314 записей, только по 14 нет информации о сборах. Посмотрим на них:

# %%
supported.query('box_office <= 0')
# Out:
#                                                   title   puNumber  \
# 2800                               золотая рыбка (2015)  111018715
# 3337                                      любовь и сакс  111001217
# 3711  колобанга. только для пользователей интернета ...  214010116
# 5661  детский юмористический киножурнал "ералаш", вы...  111011917
# 6476                                               зима  111023518
# 6709                                    мальчик русский  111002619
# 6968                                    танец с саблями  111008619
# 7009                                            куратор  111010019
# 7180                            байкал - сердце мира 3d  112004619
# 7229                                            на луне  111015519
# 7344                                      кроличья лапа  111018919
# 7474                                          вторжение  111022519
# 7476                                         я свободен  111023019
# ...

# %% [markdown]
# 10 из 14 произведений вышли в 2019 году, возможно, на момент сбора данных, ещё не было информации по прокатным сборам. 2015-2017 так оправдаться уже не могут, возможно, тут просто потери данных. В любом случае, у фильмов есть рейтинги, значит, они были представлены к показу и как минимум для оценки рейтингов их не стоит убирать из выборки.

# %%
(
    supported
    .pivot_table(index='main_genres', values=['budget', 'box_office'], aggfunc='sum')
    .sort_values(by='budget', ascending=False)
    .plot(kind='bar', figsize=(15, 7), legend=True, grid=True, alpha=0.6)
)
plt.title('Сопоставление бюджета и прокатных сборов по жанрам при гос. финансировании')
plt.ylabel('Млрд')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Исправлено, добавила заголовок</font>

# %% [markdown]
# Картина не очень оптимистичная, но могла быть и хуже. Большинство жанров не окупаются, хотя есть и исключения. Посмотрим детальнее на рентабельность:

# %%
# добавим столбец с рентабельностью
supported['profitability'] = supported['box_office'] / supported['budget'] - 1
# Out:
# /tmp/ipykernel_32456/3808901024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supported['profitability'] = supported['box_office'] / supported['budget'] - 1

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Когда выскакивают предупреждения, это означает, что в будущей новой версии библиотеки применяемый метод обработки будет не применим. Если мы планируем данный код использовать в будущем, то надо разобраться и изменить код. Если нам он в будущем не понадобится, то можно принудительно запретить вывод предупреждений вставив в ячейку с библиотеками вот такой код: <br>`pd.set_option('chained_assignment', None)` или такой: <br></font>
# `import warnings`<br>
# `warnings.filterwarnings("ignore")`

# %%
(
    supported
    .groupby('main_genres').agg('sum')
    .sort_values(by='profitability', ascending=False)
    .plot(y='profitability', kind='bar', figsize=(15, 7), legend=True, grid=True, alpha=0.6)
)
plt.title('Распределение доходности по жанрам при гос. финансировании')
plt.ylabel('%')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Исправлено добавила заголовок</font>

# %% [markdown]
# Существенный доход приносят фильмы жанра "комедия", за ними на 80% меньше, в "спорт". Незначительный, но всё же доход есть ещё от жанров "ужасы" и "биография". Все остальные идут в убыток. Самый убыточный жанр - "драма".

# %% [markdown]
# Сравним рейтинг фильмов по жанрам, которые получают гос. поддержку и нет:

# %%
def check_support(financing_source):
    if financing_source == 'без гос. финансирования':
        return 'без финансирования'
    else:
        return 'финансорованы гос-вом'

valid_data['is_supported'] = valid_data.apply(lambda x: check_support(x.financing_source), axis=1)
valid_data['is_supported']
# Out:
# /tmp/ipykernel_32456/1507261081.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_data['is_supported'] = valid_data.apply(lambda x: check_support(x.financing_source), axis=1)
# 0       без финансирования
# 1       без финансирования
# 2       без финансирования
# 3       без финансирования
# 4       без финансирования
#                ...
# 7481    без финансирования
# 7482    без финансирования
# 7483    без финансирования
# 7484    без финансирования
# 7485    без финансирования
# Name: is_supported, Length: 3849, dtype: object

# %%
(
    valid_data[valid_data.ratings != 0]
    .pivot_table(index='main_genres', columns='is_supported', values='ratings', aggfunc='median')
#     .sort_values(by='main_genres', ascending=False)
    .plot(kind='bar', figsize=(15, 7), legend=True, grid=True, alpha=0.6)
)
plt.title('Сравнение медианных рейтингов по жанрам с финансированием и без')
plt.ylabel('Прокатные сборы (млрд)')
plt.xlabel('Год')
plt.show()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Ошибка в подписи оси Y.</font><br>
# <font color='Red'>🛠 В разделе предобработки данных на пропуски рейтинга была поставлена заглушка, при анализе ее необходимо отфильтровывать<br> Для чего предназначена заглушка? Для сохранения значимых данных в других колонках, отличной той, в которой мы заменяем пропуски заглушкой. Но когда мы анализируем данные колонки с заглушками, то последнюю отфильтровываем, так как эти данные не валидны, см. код ниже. Если мы этого не делаем, то получается, что мы не совсем правильно понимаем назначение заглушки. Для учебного проекта это не очень критично, а в реальном или тестовом задании потенциального работодателя это показатель нашего не полного понимания работы с данными. Самостоятельно исправим?</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Исправлено</font>

# %%
# Комментарий ревьюера 2
valid_data.ratings.median(), valid_data[valid_data.ratings != 0].ratings.median()
# Out:
# (6.2, 6.5)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 График не оформлен полностью.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Исправлено, добавила заголовок</font>

# %% [markdown]
# По этому графику можно сделать несколько выводов:
# 1. В большинстве жанров рейтинги с гос. поддержкой и без примерно одинаковы, но "самостоятельные" картины зачастую обгоняют на доли баллов
# 2. Есть жанры, которые не стоит рассматривать, т.к. гос. поддержка на них не выделяется (аниме, для взрослых, документальный, концерт, короткометражка и музыка)
# 3. Есть жанр, который выпускается только при гос. поддержке - реальное тв (и у него достойный рейтинг 5.5)
# 4. Особой любовью зрителей пользуется криминал при гос. поддержке

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Каждый подраздел исследования должен заканчиваться промежуточным выводом.</font><br>
# </font><font color='Blue'><b>Комментарий студента</b><br>
# Добавила вывод под этим комментарием</font>

# %% [markdown]
# **Вывод по исследованию кинокартин при гос. финансировании**
# Финансируют от гусударства кинокартины два департамента: Министерство культуры и Фонд кино. Несмотря на вложенные средства, большинство (при рассмотрении в разрезе жанров) не окупаются, только 3 жанра не убыточные: драма, комедия, мультфильм.
#
# По рейтингу фильмы при гос. поддержке примерно равны с не финансируемыми (уступают всего на доли баллов), есть жанры. которые не финансируются вообще (аниме, для взрослых, документальный, концерт, короткометражка и музыка) или выпускаются только при финансировании (реальное тв) они вне сравнения. Самый любимый зрителями жанр при финансировании - криминал, но он убыточный и при сравнительно не большом финансировании, стоит обратить на него внимание, вполне возможно сделать его прибыльным, проведя маркетинговую компанию и подумав над новым сюжетами, которые будут построены не по клише.

# %% [markdown]
# ### Шаг 5. Напишите общий вывод

# %% [markdown]
# **Предобработка**
# На первой стадии анализа было выявлено, что менее 50% данных анализу подлежат по причине того, что основной показатель, по которому можно определить успех картины - прокатный сбор (*box_office*), который заполнен только 41.88% картин:
# Кол-во фильмов, для которых известны прокатные сборы: 3134, не известны: 4350
#
# Дальше необходимо было отсечь часть информации, чтобы по оставшейся получилась наиболее точная оценка и потерянные данные не искажали результат. Наиболее полно представлен период с 2015 года, всё, что было до него, пришлось убрать из анализа.
#
# **Общий анализ**
#
# Кастально общих прокатных сборов, минимальный показатель в 2015 году, немного меньше 4 млрд, максимальный - в 2018 году, почти 5 млрд. При этом в 2015 год, предположу, самый вероятно подверженный потерям данных, если вспомнить картину до отсечения записей до 2015 года. Поэтому, в среднем, за последние 4 представленных года общий сбор по прокатам составил около 4.8 млрд.
#
# При анализе прокатных сборов фильмов по возрастным категориям было выявлено:
# - Фильмы категории 16+ с 2015 до 2017 активно увеличивали свои прокатные сборы, потом, с 2017 до 2019 начали сдавать позиции, но всё ещё оставались лидерами по сборам. У фильмов категории 12+ история обратная, с 2015 до 2017 их сборы уменьшались с каждым годом, а с 2017 до 2019 начали расти и достигли в конце примерно той же отметки, что и 16+. Предположу, что такое может происходить из-за смены аудитории, когда подростки подрастают, их уже могут заинтересовать и более лёгкие к просмтору произведения. Основная разница этих возрастных категорий в том, что в фильмах 16+ относительно 12+ могут содержаться: информация о наркотических средствах, отдельные бранные слова и (или) выражения, не относящиеся к нецензурной брани, изображение или описание несчастного случая, аварии, катастрофы, заболевания, смерти без натуралистического показа их последствий. Другой вариант - изменение качества контента в категории 12+, стремительно развивается графика, в произведениях важен уже не только смысл, но и подача, и картинка (звуковое сопровождение тоже имеет значение).
# - По другим категориям, между 6+ и 18+ видно некоторое сходство динамики, за исключением 2016 года. Предположу, что это просто самый стабильный пласт, который просматривается "в быту", то, что обычно в семьях идёт на телевизоре (пусть даже на фоне).
# - Отдельно в самом низу 0+, видимо, если этот контент и смотрят, много он не собирает. Для того, чтобы получить категорию 0+ нужно соблюсти самые жёсткие рамки, оригинальный сюжет придумать сложно, а другим зрителя искушённого не привлечь.
#
# **Анализ рентаблельности фильмов при гос. поддержке**
# **Рентаблеьность**
#
# Фильмы, созданные при гос. поддерке могут иметь два возможных источника финансирования:
# - Министерство культуры
# - Фонд кино
# Некоторые картины спонсируются сразу обоими департаментами, но дальше смотрим не на это, а больше на итоговые бюджеты картин.
# За 2015-2019 год финансировались произведения множества жанров, самые финансируемые:
# - драма
# - комедия
# - мультфильм
# - приключения
# - фантастика
# - фентези
# И ещё 15 менее финансиуемых (есть жанры, которые не выпускаются при гос. поддержке вообще, это аниме, для взрослых, документальный, концерт, короткометражка и музыка).
#
# Количество снятых произведений каждого жанра связано с объёмами финансирования, особенно для первых трёх: драма, комедия, мультфильм. Что касается окупаемости, в большинстве случаев картины убыточные. Существенный доход приносят фильмы жанра "комедия", за ними на 80% меньше, в "спорт". Незначительный, но всё же доход есть ещё от жанров "ужасы" и "биография". Все остальные идут в убыток. Самый убыточный жанр - "драма" (тот самый, что активно финансируется и выпускается в прокат).
#
# **Люовь зрителя**
#
# - В большинстве жанров рейтинги с гос. поддержкой и без примерно одинаковы, но "самостоятельные" картины зачастую обгоняют на доли баллов.
# - Есть жанры, которые не стоит рассматривать, т.к. гос. поддержка на них не выделяется (аниме, для взрослых, документальный, концерт, короткометражка и музыка).
# - Есть жанр, который выпускается только при гос. поддержке - реальное тв (и у него достойный рейтинг 5.5).
# - Особой любовью зрителей пользуется криминал при гос. поддержке.
#
# **Итоговые рекомендации инвесторам**
#
# Подумать, как можно повысить доходность от самых финансируемых жанров (драма, комедия, мультфильм). Может, изменить время показа или поработать с маркетологами или даже сократить финансирование и переключить средства на более потребляемый контент. С другой стороны, подумать, поможет ли увеличение финансирования и так доходных жанров (комедия и спорт). Зрители любят криминал, а снятый при гос. поддержке даже больше, чем "самостоятельный", но это убыточный жанр на текущий момент, стоит подумать, можно ли его сделать более доходным, ведь фундамент успеха уже есть - зрителям он нравится.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно, что сделан обобщающий вывод всего исследования.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера</b></font><br><br>
# <font color='DarkGreen'>👌 Ксения, проект отлично структурирован и проработан.<br>Так держать и дальше!<br></font>
# <font color='Red'>🛠 Что нужно, что бы сделать проект лучше:</font><br>
# <font color='Red'>🛠 Необходимо сделать описание проекта. Сделать проверку и выводы об отсутствии потерь при объединении таблиц. Переделать обработку пропусков в рейтинге. Сформулировать общую проблему колонок с категориальными данными. Проверить явные (полные) дубликаты. Сделать выводы по разделу предобработки данных. Переделать раздел анализа выхода фильмов в прокат.Графики и диаграммы необходимо оформить подписями осей и названием графика/диаграммы на русском языке. Написать выводы по разделу исследовательского анализа данных. Написать выводы по разделу анализа фильмов с господдержкой.<br>После исправления ошибок необходимо будет проверить и при необхоимости откорректировать выводы анализа.</font><br>
# <font color='DarkMagenta'>👉 При исправлении ошибок и недочетов будут приобретены дополнительный опыт и навыки!</font><br>
# <font color='DarkGreen'>👌 Жду окончательный вариант! Успехов.</font><br>
# </font><font color='Blue'><b>Комментарий студента по исправлениям v1</b><br>
# Оставила комментарии под всем замечаниями, надеюсь, теперь ошибок нет =)</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 2</b></font><br><br>
# <font color='DarkGreen'>👌 Ксения! Удалось справиться со всеми заданиями в проекте. Молодец! 😄 Спасибо за работу!<br>
# Входе выполнения проекта научились анализировать первичные данные и проводить обработку датасета. Провели самостоятельный исследовательский анализ. Хочу обратить внимание на качественное оформление графиков и диаграмм, в реальном проекте на их основе затем делается презентация проекта.</font><br>
# <font color='DarkMagenta'>👉 И не забываем исправить анализ рейтингов в шаге 4.</font><br>
# <font color='DarkGreen'>👌 Теперь, вперед за новыми знаниями и навыками! Удачи! 😉</font>
# ![image.png](attachment:image.png)
